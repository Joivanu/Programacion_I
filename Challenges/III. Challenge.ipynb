# %% [markdown]
# ## Desafío 3:
#
# Administrador de contactos Crea un programa que permita administrar una lista de contactos. Cada contacto deberá tener un nombre, un número de teléfono y una dirección de correo electrónico. El programa deberá ofrecer las siguientes funcionalidades:
#
# 1. Agregar un contacto nuevo
# 2. Ver la lista de contactos
# 3. Buscar un contacto por nombre
# 4. Eliminar un contacto por nombre
#
# Usa listas y tuplas para almacenar los contactos y un diccionario para almacenar la información de cada contacto. También deberás crear distintas funciones para cada una de las funcionalidades.

# %%
# Inicializar la lista de contactos
lista_contactos = []

def agregar_contacto():
    nombre = input("Ingrese el nombre del contacto: ")
    telefono = input("Ingrese el número de teléfono del contacto: ")
    correo = input("Ingrese la dirección de correo electrónico del contacto: ")

    # Crear un diccionario para almacenar la información del contacto
    contacto = {'Nombre': nombre, 'Teléfono': telefono, 'Correo': correo}
    # Agregar el contacto a la lista
    lista_contactos.append(contacto)
    print(f'Contacto {nombre} agregado con éxito.')

def ver_lista_contactos():
    print('Lista de Contactos:')
    for contacto in lista_contactos:
        print(f"Nombre: {contacto['Nombre']}, Teléfono: {contacto['Teléfono']}, Correo: {contacto['Correo']}")

def buscar_contacto_por_nombre():
    nombre = input("Ingrese el nombre del contacto que desea buscar: ")
    for contacto in lista_contactos:
        if contacto['Nombre'] == nombre:
            print(f"Contacto encontrado - Nombre: {contacto['Nombre']}, Teléfono: {contacto['Teléfono']}, Correo: {contacto['Correo']}")
            return
    print(f"Contacto con el nombre {nombre} no encontrado.")

def eliminar_contacto_por_nombre():
    nombre = input("Ingrese el nombre del contacto que desea eliminar: ")
    for contacto in lista_contactos:
        if contacto['Nombre'] == nombre:
            lista_contactos.remove(contacto)
            print(f"Contacto {nombre} eliminado con éxito.")
            return
    print(f"Contacto con el nombre {nombre} no encontrado.")

# Menú principal
while True:
    print("\nMenú Principal:")
    print("1. Agregar un contacto")
    print("2. Ver la lista de contactos")
    print("3. Buscar un contacto por nombre")
    print("4. Eliminar un contacto por nombre")
    print("5. Salir")

    opcion = input("Ingrese el número de la opción que desea realizar: ")

    if opcion == '1':
        agregar_contacto()
    elif opcion == '2':
        ver_lista_contactos()
    elif opcion == '3':
        buscar_contacto_por_nombre()
    elif opcion == '4':
        eliminar_contacto_por_nombre()
    elif opcion == '5':
        print("Saliendo del programa. ¡Hasta luego!")
        break
    else:
        print("Opción no válida. Por favor, ingrese un número válido.")
# Out:
# Menú Principal:
# 1. Agregar un contacto
# 2. Ver la lista de contactos
# 3. Buscar un contacto por nombre
# 4. Eliminar un contacto por nombre
# 5. Salir
# Contacto Ivan Nuñez agregado con éxito.
#
# Menú Principal:
# 1. Agregar un contacto
# 2. Ver la lista de contactos
# 3. Buscar un contacto por nombre
# 4. Eliminar un contacto por nombre
# 5. Salir
# Contacto Santiago agregado con éxito.
#
# Menú Principal:
# 1. Agregar un contacto
# 2. Ver la lista de contactos
# 3. Buscar un contacto por nombre
# 4. Eliminar un contacto por nombre
# 5. Salir
# Contacto Fabiola Velarde agregado con éxito.
#
# Menú Principal:
# 1. Agregar un contacto
# 2. Ver la lista de contactos
# 3. Buscar un contacto por nombre
# 4. Eliminar un contacto por nombre
# 5. Salir
# Contacto Lulis agregado con éxito.
#
# Menú Principal:
# 1. Agregar un contacto
# 2. Ver la lista de contactos
# 3. Buscar un contacto por nombre
# 4. Eliminar un contacto por nombre
# 5. Salir
# Lista de Contactos:
# ...
